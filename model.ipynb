# %%
import numpy as np
import pandas as pd
import yfinance as yf
import seaborn as sns
import matplotlib.pyplot

# %%
ticker = yf.Ticker("AMZN")
data = ticker.history(start="2020-01-01", end="2025-10-24")
data_df = pd.DataFrame(data)
data_df.head(5)
# Out:
#                                 Open       High        Low      Close  \
# Date
# 2020-01-02 00:00:00-05:00  93.750000  94.900497  93.207497  94.900497
# 2020-01-03 00:00:00-05:00  93.224998  94.309998  93.224998  93.748497
# 2020-01-06 00:00:00-05:00  93.000000  95.184502  93.000000  95.143997
# 2020-01-07 00:00:00-05:00  95.224998  95.694504  94.601997  95.343002
# 2020-01-08 00:00:00-05:00  94.902000  95.550003  94.321999  94.598503
#
#                              Volume  Dividends  Stock Splits
# Date
# 2020-01-02 00:00:00-05:00  80580000        0.0           0.0
# 2020-01-03 00:00:00-05:00  75288000        0.0           0.0
# 2020-01-06 00:00:00-05:00  81236000        0.0           0.0
# 2020-01-07 00:00:00-05:00  80898000        0.0           0.0
# 2020-01-08 00:00:00-05:00  70160000        0.0           0.0

# %%
data_df.shape
# Out:
# (1461, 7)

# %%
data_df.describe()
# Out:
#               Open         High          Low        Close        Volume  \
# count  1461.000000  1461.000000  1461.000000  1461.000000  1.461000e+03
# mean    156.130778   158.015996   154.112221   156.107738  6.511532e+07
# std      38.373560    38.499376    38.108579    38.317950  3.337519e+07
# min      82.075500    83.480003    81.301498    81.820000  1.500750e+07
# 25%     126.059998   127.900002   124.330002   126.203003  4.269950e+07
# 50%     159.104996   160.750000   157.013000   159.119995  5.676450e+07
# 75%     180.100006   182.302994   177.490005   179.619995  7.673600e+07
# max     239.020004   242.520004   238.029999   242.059998  3.113460e+08
#
#        Dividends  Stock Splits
# count     1461.0   1461.000000
# mean         0.0      0.013689
# std          0.0      0.523245
# min          0.0      0.000000
# 25%          0.0      0.000000
# 50%          0.0      0.000000
# 75%          0.0      0.000000
# max          0.0     20.000000

# %% [markdown]
#         * df = df.fillna(method='ffill')  Remplacer par la valeur précédente (forward fill)
#         * df = df.fillna(method='bfill')  Remplacer par la valeur suivante (backward fill)
#         *  df = df.fillna(df.mean())      # moyenne
#         *  df = df.fillna(df.median())    # médiane
#         * df = df.fillna(0)   Remplacer les NaN par une valeur fixe
#         * df.dropna(inplace=True)  # supprimer les valeurs manquant
#         * df.isnull().sum()  # verifier exister valeurs manquantes

# %%
print(data_df.isnull().sum())
# Out:
# Open            0
# High            0
# Low             0
# Close           0
# Volume          0
# Dividends       0
# Stock Splits    0
# dtype: int64

# %%
# normalisation data
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
data_df_scaler = scaler.fit_transform(data_df)

# %%
data_df_scaler
# Out:
# array([[-1.62617536, -1.6399515 , -1.59873656, ...,  0.46351702,
#          0.        , -0.0261712 ],
#        [-1.63986138, -1.65529466, -1.59827714, ...,  0.30490185,
#          0.        , -0.0261712 ],
#        [-1.64572676, -1.63257212, -1.6041833 , ...,  0.48317906,
#          0.        , -0.0261712 ],
#        ...,
#        [ 1.62404914,  1.69681637,  1.67677879, ..., -0.43822161,
#          0.        , -0.0261712 ],
#        [ 1.64672903,  1.61081118,  1.63819156, ..., -0.62363531,
#          0.        , -0.0261712 ],
#        [ 1.63890839,  1.64432991,  1.68176591, ..., -1.00634087,
#          0.        , -0.0261712 ]], shape=(1461, 7))

# %%
sns.relplot(data=data_df, x='Date',y='Close')

# %%
sns.relplot(data=data_df, x='Date',y='Stock Splits')
