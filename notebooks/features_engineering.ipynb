# %%
import sys
import os
import pandas as pd

# %%
sys.path.append(os.path.abspath('../src'))

# %%
from features import add_technical_indicators

# %%
data_df = pd.read_csv('../data/raw/amzn.parquet')

# %%
nv_data_df = add_technical_indicators(data_df)

# %%
nv_data_df
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2020-01-02 00:00:00-05:00   93.750000   94.900497   93.207497   94.900497
# 2020-01-03 00:00:00-05:00   93.224998   94.309998   93.224998   93.748497
# 2020-01-06 00:00:00-05:00   93.000000   95.184502   93.000000   95.143997
# 2020-01-07 00:00:00-05:00   95.224998   95.694504   94.601997   95.343002
# 2020-01-08 00:00:00-05:00   94.902000   95.550003   94.321999   94.598503
# ...                               ...         ...         ...         ...
# 2025-10-17 00:00:00-04:00  214.559998  214.800003  211.029999  213.039993
# 2025-10-20 00:00:00-04:00  213.880005  216.690002  213.589996  216.479996
# 2025-10-21 00:00:00-04:00  218.429993  223.320007  217.990005  222.029999
# 2025-10-22 00:00:00-04:00  219.300003  220.009995  216.520004  217.949997
# 2025-10-23 00:00:00-04:00  219.000000  221.300003  218.179993  221.089996
#
#                              Volume        MA20      MA50     BB_high  \
# ...

# %%
nv_data_df.dropna().to_csv('../data/processed/amzn_processed')

# %%
display(nv_data_df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1461 entries, 2020-01-02 00:00:00-05:00 to 2025-10-23 00:00:00-04:00
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Open     1461 non-null   float64
#  1   High     1461 non-null   float64
#  2   Low      1461 non-null   float64
#  3   Close    1461 non-null   float64
#  4   Volume   1461 non-null   int64
#  5   MA20     1442 non-null   float64
#  6   MA50     1412 non-null   float64
#  7   BB_high  1442 non-null   float64
#  8   BB_low   1442 non-null   float64
#  9   rsi      1448 non-null   float64
# dtypes: float64(9), int64(1)
# memory usage: 125.6 KB
# None
